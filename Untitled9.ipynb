# %%
a=[10,20,30,20,40]
a.append(50)
print(a)
a.insert(5, 60)
print(a)
a.extend((70, 80))
print(a)
a.pop()
print(a)
a.remove(20)
print(a)
a.index(50)
# Out:
# [10, 20, 30, 20, 40, 50]
# [10, 20, 30, 20, 40, 60, 50]
# [10, 20, 30, 20, 40, 60, 50, 70, 80]
# [10, 20, 30, 20, 40, 60, 50, 70]
# [10, 30, 20, 40, 60, 50, 70]
# []

# %%
a=[10,20,30,20,40]
a.count(10)
# Out:
# 1

# %%
a=[10,30.49,20]
a.sort() 
print(a)
# Out:
# [10, 20, 30.49]

# %%
a=[10,30.49,20]
a.reverse()
print(a)
# Out:
# [20, 30.49, 10]

# %%
a=[10,30.49,20]
a.clear()
print(a)
# Out:
# []

# %%
a=[10,30.49,20]
b=[]
b=a.copy()
print(b)
# Out:
# [10, 30.49, 20]
