# %%
num1=int(input("enter the no."))
num2=int(input("enter the no."))
print(num1+num2)
print(num1*num2)
print(num1==num2)
print(num1>num2)
a=[10,20,30,40,50]
print(10 in a)
print(30 in a)
# Out:
# enter the no. 10
# enter the no. 10
# 20
# 100
# True
# False
# True
# True
