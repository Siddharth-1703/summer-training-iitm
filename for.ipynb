# %%
#for loop
# print numbers

# %%
num = int(input("Enter a number: "))
for i in range(1, 10):
    print(f"{num} x {i} = {num * i}")
# Out:
# Enter a number:  10
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90

# %%
if 5 > 3:
    print('Yes')
# Out:
# Yes

# %%
10 / 5
# Out:
# 2.0

# %%
type(True)
# Out:
# bool

# %%
if 0: 
     print('Yes')

# %%
if x == 5 and x < 10:
# Out:
#   Cell In[12], line 1
#     if x == 5 and x < 10:
#                          ^
# _IncompleteInputError: incomplete input

# %%
10 // 3
# Out:
# 3

# %%
for i in range(3):
    if i == 1:
        continue;
        print(i)

# %%
 if True and False:
# Out:
#   Cell In[17], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %%
3 + 2 * 2
# Out:
# 7

# %%
 5 != 5
# Out:
# False

# %%
 2 ** 3
# Out:
# 8

# %%
10 % 3
# Out:
# 1
