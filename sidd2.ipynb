# %%
x=int(input("enter the no"))
y=int(input("enter the no."))
z=int(input("enter the no."))
sum=x+y+z
print(sum)
avg=sum/3
print(avg)
print(avg>50)
print(sum/5)
# Out:
# enter the no. 10
# enter the no. 20
# enter the no. 30
# 60
# 20.0
# False
# 12.0
