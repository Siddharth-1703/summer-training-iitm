# %%
name=str(input("enter the name of product"))
quantity=int(input("enter the quantity"))
price=int(input("enter the price"))
amount=quantity*price
print(name,amount)
# Out:
# enter the name of product abc
# enter the quantity 10
# enter the price 5
# abc 50
