# %%
#datatype(basic)

# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
a=4.6 
print(type(a))
# Out:
# <class 'float'>

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
a=3
print(type(str(a)))
# Out:
# <class 'str'>

# %%
a=3
b=str(a)
print(type(b))
# Out:
# <class 'str'>

# %%
#arthmetic operators

# %%
+,-,*,/,%,//,**

# %%
a=3
b=4
print(a+b)
# Out:
# 7

# %%
a=int(input("enter the no."))
b=int(input("enter the no."))
print(a-b)
# Out:
# enter the no. 4
# enter the no. 2
# 2

# %%
a=3
b=4
print(a*b)
# Out:
# 12

# %%
a=4
b=2
print(a/b)
# Out:
# 2.0

# %%
a=5
b=2
print(a%b)
# Out:
# 1

# %%
a=8
b=3
print(a//b)
# Out:
# 2

# %%
a=4
b=5
print(a**b)
# Out:
# 1024

# %%
#comparison operator

# %%
<,>,<=,>=,==,!=

# %%
a=5
b=6
print(a<b)
# Out:
# True

# %%
a=5
b=6
print(a>b)
# Out:
# False

# %%
a=6
b=4
print(a<=b)
# Out:
# False

# %%
a=6
b=4
print(a>=b)
# Out:
# True

# %%
a=4
b=4
print(a==b)
# Out:
# True

# %%
a=6
b=4
print(a!=b)
# Out:
# True

# %%
#logical operators

# %%
and,or,not

# %%
a=5
b=6
print(a>b and a==b)
# Out:
# False

# %%
a=5
b=6
print(a>b or a==b)
# Out:
# True

# %%
a=6
b=5
print(not (a>b))
# Out:
# False

# %%
#membership operator

# %%
in,not in

# %%
a=[2,3,4,5]
for x in a:
      print(x)
# Out:
# 2
# 3
# 4
# 5

# %%
a="python is imp"
print("is" in a)
# Out:
# True

# %%
a="python is imp"
print("is" not in a)
# Out:
# False

# %%
#identity operator
is,is not

# %%
a=5
b=5
print(a is b)
# Out:
# True

# %%
a=5
b=5
print(a is not b)
# Out:
# False
